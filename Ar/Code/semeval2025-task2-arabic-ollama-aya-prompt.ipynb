# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
    # for filename in filenames:
    #     print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# !pip -q install --upgrade ollama

# %%
# !curl -fsSL https://ollama.com/install.sh | sh
# Out:
# >>> Installing ollama to /usr/local
# >>> Downloading Linux amd64 bundle
# ############################################################################################# 100.0%#                                                                                 15.3%#########################                                                             37.5%############################################################                                68.7%
# >>> Creating ollama user...
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# WARNING: systemd is not running
# WARNING: Unable to detect NVIDIA/AMD GPU. Install lspci or lshw to automatically detect and install GPU dependencies.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.

# %%
import os
get_ipython().system = os.system

# %%
# !ollama serve &
# Out:
# 0

# %%
# !ollama pull aya:8b
# Out:
# 0

# %%
# !ollama show aya:8b
# Out:
# 0

# %%
import json
from tqdm import tqdm
import ollama

# from langchain_community.chat_models import ChatOllama
# from langchain.document_loaders import WikipediaLoader
# # from langchain_community.llms import Ollama
# from langchain_ollama import OllamaLLM
# from langchain.chains import LLMChain
# from langchain.prompts.chat import (ChatPromptTemplate,HumanMessagePromptTemplate,SystemMessagePromptTemplate)
# from langchain import PromptTemplate

# %%
# Path to your input and output files
input_file = "/kaggle/input/task-2-ea-mt-entity-aware-machine-translation/ar_AE_after_eb6159800a5a89cc.jsonl"
output_file = "translated_data_en_ar_after_eb6159800a5a89ccollama-aya-8b-v1.jsonl"

# %%
def translate_text(obj):
    prompt = f"""
    Translate the following English text into Arabic with a more attention on accurately translating the given name entities. 
    Do not add extra text.
    
    Entity Types: {', '.join(obj['entity_types'])}
    Text: "{obj['source']}"
    
    Output the result in JSON format:
    {{
        "id": "{obj['id']}",
        "predicted_text": "<translated_text>"
    }}
    """
    
    response = ollama.chat(
        model="aya:8b",
        messages=[{"role": "system", "content": "You are a translation assistant."},
                  {"role": "user", "content": prompt}],
        stream=False
    )
    
    # Extract generated text and parse JSON
    try:
        # print(response)
        output_json = json.loads(response.message.content)
        return output_json
    except json.JSONDecodeError:
        print(f"Error parsing response for ID: {obj['id']}")
        return None

# %%
with open(input_file, "r", encoding="utf-8") as f:
    total_lines = sum(1 for _ in f)

# %%
# Read input file and translate each object
with open(input_file, "r", encoding="utf-8") as infile, open(output_file, "w", encoding="utf-8") as outfile:
    with tqdm(total=total_lines, desc="Generating Predictions", colour="blue") as pbar:
            for line in infile:
                obj = json.loads(line.strip())
                translated_obj = translate_text(obj)
                # print("Before: ", translated_obj)
                
                # print("After: ", translated_obj)
                # break
                if translated_obj:
                    translated_obj = {
                    "id": obj["id"],
                    "source_language": "English",
                    "target_language": "Arabic", 
                    "text": obj["source"],
                    "prediction": translated_obj["predicted_text"]
                    
                    }
                    outfile.write(json.dumps(translated_obj, ensure_ascii=False) + "\n")
                pbar.update(1)

print(f"Translation completed! Output saved to {output_file}")
# Out:
# Generating Predictions:   1%|          | 13/2540 [00:24<1:01:02,  1.45s/it]
# Error parsing response for ID: 467ce5559a1ba8cd
# Generating Predictions:   1%|          | 24/2540 [00:43<1:04:06,  1.53s/it]
# Error parsing response for ID: b356561f0353cda0
# Generating Predictions:   2%|▏         | 63/2540 [01:50<1:19:20,  1.92s/it]
# Error parsing response for ID: e09cb095ef146a4d
# Generating Predictions:   5%|▌         | 132/2540 [04:09<1:21:27,  2.03s/it]
# Error parsing response for ID: 8f4780e53c3afb9b
# Generating Predictions:   6%|▌         | 157/2540 [05:02<1:28:11,  2.22s/it]
# Error parsing response for ID: 05eac5e5713ba5ae
# Generating Predictions:   6%|▋         | 163/2540 [05:13<1:09:20,  1.75s/it]
# Error parsing response for ID: eab56c7ffaf6578e
# Generating Predictions:   8%|▊         | 204/2540 [06:34<1:15:36,  1.94s/it]
# Error parsing response for ID: 995370c6a13e6f5c
# Generating Predictions:   9%|▊         | 217/2540 [07:04<1:59:05,  3.08s/it]
# Error parsing response for ID: 4a4c1cdf7333cfc6
# Generating Predictions:  11%|█▏        | 286/2540 [09:28<1:14:15,  1.98s/it]
# Error parsing response for ID: 26421df64cecef30
# Generating Predictions:  14%|█▎        | 347/2540 [11:28<1:14:00,  2.02s/it]
# Error parsing response for ID: cc9244c9f708e034
# Generating Predictions:  15%|█▍        | 375/2540 [12:23<1:10:14,  1.95s/it]
# Error parsing response for ID: 49257bdd94773588
# Generating Predictions:  15%|█▍        | 379/2540 [12:32<1:20:46,  2.24s/it]
# Error parsing response for ID: 92dec93edfb693b3
# Generating Predictions:  17%|█▋        | 420/2540 [13:58<1:41:52,  2.88s/it]
# Error parsing response for ID: c4f7145fe24e1b18
# Generating Predictions:  21%|██▏       | 546/2540 [18:22<1:07:49,  2.04s/it]
# Error parsing response for ID: bf08cefc7974bf6d
# Generating Predictions:  22%|██▏       | 556/2540 [18:43<1:12:32,  2.19s/it]
# Error parsing response for ID: 4e4dcc676881a3cc
# Generating Predictions:  25%|██▍       | 629/2540 [21:15<1:23:51,  2.63s/it]
# Error parsing response for ID: 38399970828ba203
# Generating Predictions:  26%|██▋       | 668/2540 [22:44<1:03:06,  2.02s/it]
# Error parsing response for ID: 753bb7af67e3ec17
# Generating Predictions:  29%|██▉       | 735/2540 [24:59<1:00:07,  2.00s/it]
# Error parsing response for ID: 124d9751b3b57a1f
# Generating Predictions:  31%|███       | 778/2540 [26:24<1:03:32,  2.16s/it]
# Error parsing response for ID: 7a5513840df82faa
# Generating Predictions:  37%|███▋      | 938/2540 [31:43<52:58,  1.98s/it]
# Error parsing response for ID: 345a268c7cb04863
# Generating Predictions:  43%|████▎     | 1098/2540 [37:10<44:44,  1.86s/it]
# Error parsing response for ID: afaea3d26d8a7769
# Generating Predictions:  43%|████▎     | 1100/2540 [37:14<45:03,  1.88s/it]
# Error parsing response for ID: e73a7118934b15e1
# Generating Predictions:  44%|████▍     | 1121/2540 [37:59<51:14,  2.17s/it]
# Error parsing response for ID: e9b3bb926ad5ea74
# Generating Predictions:  46%|████▋     | 1177/2540 [39:55<47:59,  2.11s/it]
# Error parsing response for ID: bafc9d9dd18fe37a
# Generating Predictions:  48%|████▊     | 1221/2540 [41:36<43:35,  1.98s/it]
# Error parsing response for ID: eeccf750594a7729
# Generating Predictions:  48%|████▊     | 1226/2540 [41:46<44:36,  2.04s/it]
# Error parsing response for ID: 281d3021c6a4c94f
# Generating Predictions:  49%|████▉     | 1246/2540 [42:28<43:11,  2.00s/it]
# Error parsing response for ID: 0e13935c811d8e9d
# Generating Predictions:  50%|█████     | 1272/2540 [43:20<43:23,  2.05s/it]
# Error parsing response for ID: 5fb7354704ad0be2
# Generating Predictions:  52%|█████▏    | 1324/2540 [45:03<49:46,  2.46s/it]
# Error parsing response for ID: 76779d2760406bf3
# Generating Predictions:  52%|█████▏    | 1328/2540 [45:11<44:07,  2.18s/it]
# Error parsing response for ID: f3202436c4805f79
# Generating Predictions:  53%|█████▎    | 1337/2540 [45:30<43:27,  2.17s/it]
# Error parsing response for ID: 7be4d4c752a3d8e7
# Generating Predictions:  54%|█████▍    | 1370/2540 [46:36<36:23,  1.87s/it]
# Error parsing response for ID: 380953d750c1b756
# Generating Predictions:  55%|█████▍    | 1385/2540 [47:08<50:14,  2.61s/it]
# Error parsing response for ID: b05159c78a85360b
# Generating Predictions:  57%|█████▋    | 1443/2540 [49:03<36:49,  2.01s/it]
# Error parsing response for ID: 5c8faa1b43dc168b
# Generating Predictions:  57%|█████▋    | 1460/2540 [49:37<35:05,  1.95s/it]
# Error parsing response for ID: c4277c06bdc8a59c
# Generating Predictions:  58%|█████▊    | 1468/2540 [49:54<37:46,  2.11s/it]
# Error parsing response for ID: 58dff50d34cb2b9b
# Generating Predictions:  58%|█████▊    | 1472/2540 [50:02<36:27,  2.05s/it]
# Error parsing response for ID: c2ce0b15fb845c44
# Generating Predictions:  60%|██████    | 1532/2540 [52:02<35:01,  2.08s/it]
# Error parsing response for ID: 0da36c50b547554e
# Generating Predictions:  62%|██████▏   | 1577/2540 [53:40<1:01:19,  3.82s/it]
# Error parsing response for ID: f9f1d931fde4031a
# Generating Predictions:  64%|██████▍   | 1628/2540 [55:25<30:24,  2.00s/it]
# Error parsing response for ID: 05561338e9195874
# Generating Predictions:  65%|██████▍   | 1639/2540 [55:48<37:15,  2.48s/it]
# Error parsing response for ID: 4672e5ae2a82bc7c
# Generating Predictions:  66%|██████▌   | 1668/2540 [56:43<29:47,  2.05s/it]
# Error parsing response for ID: f5446655a3a23344
# Generating Predictions:  76%|███████▌  | 1919/2540 [1:05:29<22:20,  2.16s/it]
# Error parsing response for ID: dd8f62ae97545adb
# Generating Predictions:  76%|███████▌  | 1933/2540 [1:06:00<22:13,  2.20s/it]
# Error parsing response for ID: 7908d22fc70535ad
# Generating Predictions:  78%|███████▊  | 1990/2540 [1:07:53<19:41,  2.15s/it]
# Error parsing response for ID: c533fb62e611d654
# Generating Predictions:  79%|███████▊  | 1997/2540 [1:08:07<18:37,  2.06s/it]
# Error parsing response for ID: 04fe4dbdd6673575
# Generating Predictions:  81%|████████▏ | 2069/2540 [1:10:36<15:19,  1.95s/it]
# Error parsing response for ID: be4022c3cb09a534
# Generating Predictions:  86%|████████▋ | 2191/2540 [1:14:41<11:36,  1.99s/it]
# Error parsing response for ID: 08e76a21f2dee6ba
# Generating Predictions:  94%|█████████▎| 2381/2540 [1:21:11<05:04,  1.92s/it]
# Error parsing response for ID: 9cbcbb00d11404b2
# Generating Predictions:  95%|█████████▍| 2406/2540 [1:22:04<04:37,  2.07s/it]
# Error parsing response for ID: a65244c01361fdb1
# Generating Predictions:  99%|█████████▊| 2502/2540 [1:25:23<01:18,  2.06s/it]
# Error parsing response for ID: 0cef68fa6b0adc63
# Generating Predictions:  99%|█████████▉| 2523/2540 [1:26:06<00:34,  2.05s/it]
# Error parsing response for ID: ac00b3bf7cc53cd0
# Generating Predictions: 100%|██████████| 2540/2540 [1:26:45<00:00,  2.05s/it]
# Translation completed! Output saved to translated_data_en_ar_after_eb6159800a5a89ccollama-aya-8b-v1.jsonl
